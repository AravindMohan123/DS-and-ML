# %% [markdown]
# <a href="https://colab.research.google.com/github/AravindMohan123/DS-and-ML/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Read the dataset from CSV
df = pd.read_csv('/content/drive/MyDrive/salaries (2).csv')

# Convert categorical variables to numerical using one-hot encoding
df = pd.get_dummies(df, columns=['company', 'job', 'degree'])

# Separate features and target variable
X = df.drop('salary_more_then_100k', axis=1)
y = df['salary_more_then_100k']

# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=40)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier()

# Fit the classifier on the training data
clf.fit(X_train, y_train)

# Predict using the test set
y_pred = clf.predict(X_test)

# Calculate accuracy on the test set
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the Decision Tree model on test data: {accuracy:.2f}")

# Plot the decision tree
plt.figure(figsize=(12, 8))
plot_tree(clf, feature_names=X.columns, class_names=['<=100k', '>100k'], filled=True, rounded=True)
plt.show()
# Out:
# Accuracy of the Decision Tree model on test data: 1.00

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Read the dataset from CSV
df = pd.read_csv('/content/drive/MyDrive/salaries (2).csv')

# Convert categorical variables to numerical using one-hot encoding
df = pd.get_dummies(df, columns=['company', 'job', 'degree'])

# Separate features and target variable
X = df.drop('salary_more_then_100k', axis=1)
y = df['salary_more_then_100k']

# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Initialize the Decision Tree Classifier with entropy and max_depth
clf = DecisionTreeClassifier(criterion='entropy', max_depth=4)  # Set your desired max_depth value

# Fit the classifier on the training data
clf.fit(X_train, y_train)

# Predict using the test set
y_pred = clf.predict(X_test)

# Calculate accuracy on the test set
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the Decision Tree model on test data: {accuracy:.2f}")

# Plot the decision tree
plt.figure(figsize=(12, 8))
plot_tree(clf, feature_names=X.columns, class_names=['<=100k', '>100k'], filled=True, rounded=True)
plt.show()
# Out:
# Accuracy of the Decision Tree model on test data: 1.00
